# %% [markdown]
# ## Paquetes de la imagen actual
#
# La imagen que utiliza cada servidor se encuentra en el [repositorio oficial de JupyterHub](https://quay.io/repository/jupyter/pyspark-notebook?tab=tags), la elección fue hecha en base a las necesidades de los estudiantes, usando de referencia su [documentación oficial](https://jupyter-docker-stacks.readthedocs.io/en/latest/using/selecting.html)

# %%
# Versión de Python
# !python --version
# Out:
# Python 3.13.13

# %%
# Paquetes en Python pip
# !python -m pip list
# Out:
# Package                   Version
# ------------------------- ------------
# alembic                   1.18.4
# altair                    6.1.0
# annotated-types           0.7.0
# anyio                     4.13.0
# archspec                  0.2.5
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# backports.zstd            1.4.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# blinker                   1.9.0
# bokeh                     3.9.0
# boltons                   25.0.0
# Bottleneck                1.6.0
# Brotli                    1.2.0
# cached-property           1.5.2
# certifi                   2026.4.22
# certipy                   0.2.3
# cffi                      2.0.0
# charset-normalizer        3.4.7
# click                     8.3.3
# ...

# %%
# Paquetes de R
# !R -q -e "installed.packages()[,c('Package','Version')]"
# Out:
# > installed.packages()[,c('Package','Version')]
#              Package        Version
# SparkR       "SparkR"       "4.1.1"
# askpass      "askpass"      "1.2.1"
# base         "base"         "4.5.3"
# base64enc    "base64enc"    "0.1-6"
# bitops       "bitops"       "1.0-9"
# blob         "blob"         "1.3.0"
# cli          "cli"          "3.6.6"
# codetools    "codetools"    "0.2-20"
# colorspace   "colorspace"   "2.1-2"
# compiler     "compiler"     "4.5.3"
# config       "config"       "0.3.2"
# cpp11        "cpp11"        "0.5.4"
# crayon       "crayon"       "1.5.3"
# curl         "curl"         "7.1.0"
# datasets     "datasets"     "4.5.3"
# DBI          "DBI"          "1.3.0"
# dbplyr       "dbplyr"       "2.5.2"
# digest       "digest"       "0.6.39"
# dplyr        "dplyr"        "1.2.1"
# ellipsis     "ellipsis"     "0.3.3"
# evaluate     "evaluate"     "1.0.5"
# fansi        "fansi"        "1.0.7"
# farver       "farver"       "2.1.2"
# ...

# %%
# Versión de Spark
# !spark-submit --version
# !python -c "import pyspark; print(pyspark.__version__)"
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 4.1.1
#       /_/
#
# Using Scala version 2.13.17, OpenJDK 64-Bit Server VM, 21.0.10
# Branch HEAD
# Compiled by user runner on 2026-01-02T11:55:02Z
# Revision c0690c763bafabd08e7079d1137fa0a769a05bae
# Url https://github.com/apache/spark
# Type --help for more information.
# 4.1.1

# %%
# Paquetes de Conda
# !conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                              Version          Build                    Channel
# _openmp_mutex                       4.5              20_gnu                   conda-forge
# _python_abi3_support                1.0              hd8ed1ab_2               conda-forge
# _r-mutex                            1.0.1            anacondar_1              conda-forge
# alembic                             1.18.4           pyhcf101f3_0             conda-forge
# altair                              6.1.0            pyhd8ed1ab_0             conda-forge
# annotated-types                     0.7.0            pyhd8ed1ab_1             conda-forge
# anyio                               4.13.0           pyhcf101f3_0             conda-forge
# aom                                 3.9.1            hac33072_0               conda-forge
# archspec                            0.2.5            pyhd8ed1ab_0             conda-forge
# ...
